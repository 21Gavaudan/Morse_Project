# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Read binary samples
samples = np.fromfile("data/samples/long_text_sin.bin", dtype=np.int16)

# %%
samples.shape
Y = [i for i in range(len(samples))]
plt.plot(Y[:1000], samples[:1000])
plt.show()
